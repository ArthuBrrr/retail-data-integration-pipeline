# %%
import pandas as pd 

data_stats_dvf= pd.read_csv("../data_lake/raw/stats_dvf.csv")
data2_stats_whole_period = pd.read_csv("../data_lake/raw/stats_whole_period.csv")

# %%
data_stats_dvf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3640344 entries, 0 to 3640343
# Data columns (total 17 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   code_geo                 str
#  1   nb_ventes_maison         float64
#  2   moy_prix_m2_maison       float64
#  3   med_prix_m2_maison       float64
#  4   nb_ventes_appartement    float64
#  5   moy_prix_m2_appartement  float64
#  6   med_prix_m2_appartement  float64
#  7   nb_ventes_local          float64
#  8   moy_prix_m2_local        float64
#  9   med_prix_m2_local        float64
#  10  nb_ventes_apt_maison     int64
#  11  moy_prix_m2_apt_maison   int64
#  12  med_prix_m2_apt_maison   int64
#  13  annee_mois               str
#  14  libelle_geo              str
#  15  code_parent              str
#  16  echelle_geo              str
# dtypes: float64(9), int64(3), str(5)
# memory usage: 472.2 MB

# %%
data_stats_dvf.head()
# Out:
#   code_geo  nb_ventes_maison  moy_prix_m2_maison  med_prix_m2_maison  \
# 0       01             516.0              2343.0              2135.0
# 1       01             375.0              2491.0              2269.0
# 2       01             594.0              2392.0              2224.0
# 3       01             665.0              2379.0              2136.0
# 4       01             522.0              2451.0              2212.0
#
#    nb_ventes_appartement  moy_prix_m2_appartement  med_prix_m2_appartement  \
# 0                  315.0                   2822.0                   2485.0
# 1                  197.0                   2735.0                   2407.0
# 2                  300.0                   2812.0                   2415.0
# 3                  322.0                   2879.0                   2606.0
# 4                  270.0                   2759.0                   2416.0
#
#    nb_ventes_local  moy_prix_m2_local  med_prix_m2_local  \
# ...

# %%
data2_stats_whole_period.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 413223 entries, 0 to 413222
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   code_geo                       413223 non-null  str
#  1   libelle_geo                    413196 non-null  str
#  2   code_parent                    413223 non-null  str
#  3   echelle_geo                    413223 non-null  str
#  4   nb_ventes_whole_appartement    66103 non-null   float64
#  5   moy_prix_m2_whole_appartement  66103 non-null   float64
#  6   med_prix_m2_whole_appartement  66103 non-null   float64
#  7   nb_ventes_whole_maison         287091 non-null  float64
#  8   moy_prix_m2_whole_maison       287091 non-null  float64
#  9   med_prix_m2_whole_maison       287091 non-null  float64
#  10  nb_ventes_whole_apt_maison     290669 non-null  float64
#  11  moy_prix_m2_whole_apt_maison   290669 non-null  float64
# ...

# %%
data2_stats_whole_period.head()
# Out:
#      code_geo              libelle_geo code_parent  echelle_geo  \
# 0          01                      Ain      nation  departement
# 1       01001  L'Abergement-Clemenciat   200069193      commune
# 2  010010000A               010010000A       01001      section
# 3  010010000B               010010000B       01001      section
# 4  01001000ZA               01001000ZA       01001      section
#
#    nb_ventes_whole_appartement  moy_prix_m2_whole_appartement  \
# 0                      16023.0                         3108.0
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#    med_prix_m2_whole_appartement  nb_ventes_whole_maison  \
# 0                         2705.0                 26280.0
# 1                            NaN                    40.0
# ...
